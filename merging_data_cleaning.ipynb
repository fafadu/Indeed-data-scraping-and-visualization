# %%
import pandas as pd
import re

# %%
jobs_df = pd.read_csv("indeed_jobs.csv")  # Contains "Job URL"
details_df = pd.read_csv("job_detail3.csv")  # Contains "URL"

# Ensure the column names match (rename if they don't)
jobs_df.rename(columns={"Job URL": "URL"}, inplace=True)

# Remove duplicates, keeping only the first occurrence for each URL
jobs_df = jobs_df.drop_duplicates(subset="URL")
details_df = details_df.drop_duplicates(subset="URL")

# Merge the two DataFrames based on the "URL" column
df = pd.merge(jobs_df, details_df, on="URL", how="inner")
print(jobs_df.shape)
print(details_df.shape)
print(df.shape)

# Save the merged result to a CSV file
df.to_csv("merged.csv", index=False)
print("CSV merge completed")
# Out:
# (210, 2)
# (266, 10)
# (208, 11)
# 合併完成csv'

# %%
print(jobs_df.shape)
print(details_df .shape)
print(df.shape)
# Out:
# (210, 2)
# (266, 10)
# (208, 11)

# %%
# Check for duplicate URLs in jobs_df
print(jobs_df['URL'].duplicated().sum())

# Check for duplicate URLs in details_df
print(details_df['URL'].duplicated().sum())
# Out:
# 0
# 0

# %%
pd.set_option('display.max_rows', 250)

# Define the extraction function
def extract_parts(location):
    if pd.isna(location):  # If the location is NaN, return None for each part
        return None, None, None
    
    # Use regular expressions to match
    state_match = re.search(r'\b(QLD|VIC|NSW|SA|WA|TAS|NT|ACT)\b', location)
    postcode_match = re.search(r'\b(\d{4})\b', location)
    
    # Extract State and Postcode
    state = state_match.group(1) if state_match else None
    postcode = postcode_match.group(1) if postcode_match else None
    
    # The suburb is the remaining part after removing the State and Postcode
    suburb = re.sub(r'\b(QLD|VIC|NSW|SA|WA|TAS|NT|ACT)\b', '', location)  # Remove State
    suburb = re.sub(r'\b(\d{4})\b', '', suburb)  # Remove Postcode
    suburb = suburb.strip()  # Remove any extra spaces
    
    return suburb, state, postcode

# Apply the function to each 'Location'
df[['Suburb', 'State', 'Postcode']] = df['Location'].apply(lambda x: pd.Series(extract_parts(x)))
df = df.loc[:, ~df.columns.str.startswith('Unnamed:')]

# Display the result
print(df)

# Save the result to a CSV file
df.to_csv("m2.csv", index=False)

# %%
# Out:
#                                              Job Title  \
# 0                            BUSINESS INSIGHTS ANALYST
# 1                                 ICT Business Analyst
# 2    Business Analyst - Cards & Digital Wallets, AN...
# 3    Quantitative/Senior Quantitative Analyst - Sun...
# 4                      Online Data Analyst - Australia
# ..                                                 ...
# 203                                Senior Data Analyst
# 204                         Database Developer Analyst
# 205                         Franchise Business Analyst
# 206                                Senior Data Analyst
# 207                             Head of Data Analytics
#
#                                                    URL               Company  \
# 0    https://au.indeed.com/pagead/clk?mo=r&ad=-6NYl...        liquor legends
# 1    https://au.indeed.com/pagead/clk?mo=r&ad=-6NYl...   Tenbagsfull PTY LTD
# 2    https://au.indeed.com/pagead/clk?mo=r&ad=-6NYl...     ANZ Banking Group
# 3    https://au.indeed.com/pagead/clk?mo=r&ad=-6NYl...     ANZ Banking Group
# 4    https://au.indeed.com/rc/clk?jk=ea5d52910851e4...       TELUS Digital -
# ..                                                 ...                   ...
# 203  https://au.indeed.com/rc/clk?jk=fb4d57f6b58bc4...                  TMGM
# 204  https://au.indeed.com/rc/clk?jk=003e16771f7542...             SA Health
# 205  https://au.indeed.com/rc/clk?jk=b32180d15da369...                Snooze
# 206  https://au.indeed.com/rc/clk?jk=4952c1cddd17c3...  Colonial First State
# 207  https://au.indeed.com/rc/clk?jk=102d07027ec06d...               Bellroy
#
#                   Location                                    Job Description  \
# 0    Yeerongpilly QLD 4105  Liquor Legends is considered ?est in Class Li...
# 1                      NaN  Full-time position\nRemote/hybrid\nAn ICT Busi...
# 2            Melbourne VIC  Req ID: 85993\nDepartment: AR ANZx Manage My M...
# 3             Brisbane QLD  Job Title: Quantitative/Senior Quantitative An...
# 4         Bulleen VIC 3105  No previous professional experience is require...
# ..                     ...                                                ...
# 203             Sydney NSW  We are seeking a highly analytical and detail-...
# 204    Greater Adelaide SA  Job no: 892204\nWork type: Full time\nLocation...
# 205    Canterbury VIC 3126  Snooze Management, based in leafy Canterbury i...
# 206             Sydney NSW  Are you ready to be part of an organisation th...
# 207        Collingwood VIC  IN A NUTSHELL\nAt Bellroy, we believe that ins...
#
#                Suburb State Postcode
# 0        Yeerongpilly   QLD     4105
# 1                None  None     None
# 2           Melbourne   VIC     None
# 3            Brisbane   QLD     None
# 4             Bulleen   VIC     3105
# ..                ...   ...      ...
# 203            Sydney   NSW     None
# 204  Greater Adelaide    SA     None
# 205        Canterbury   VIC     3126
# 206            Sydney   NSW     None
# 207       Collingwood   VIC     None
#
# [208 rows x 8 columns]
